# %%
# !pip install confluent-kafka
# Out:
# Collecting confluent-kafka
#   Downloading confluent_kafka-2.5.0-cp312-cp312-win_amd64.whl.metadata (2.4 kB)
# Downloading confluent_kafka-2.5.0-cp312-cp312-win_amd64.whl (3.5 MB)
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/3.5 MB 165.2 kB/s eta 0:00:22
#    ---------------------------------------- 0.0/3.5 MB 165.2 kB/s eta 0:00:22
#    ---------------------------------------- 0.0/3.5 MB 196.9 kB/s eta 0:00:18
#     --------------------------------------- 0.1/3.5 MB 252.2 kB/s eta 0:00:14
#    - -------------------------------------- 0.1/3.5 MB 350.1 kB/s eta 0:00:10
#    - -------------------------------------- 0.2/3.5 MB 482.7 kB/s eta 0:00:08
#    -- ------------------------------------- 0.2/3.5 MB 655.6 kB/s eta 0:00:06
#    --- ------------------------------------ 0.3/3.5 MB 710.0 kB/s eta 0:00:05
#    ---- ----------------------------------- 0.4/3.5 MB 825.0 kB/s eta 0:00:04
#    ----- ---------------------------------- 0.5/3.5 MB 1.0 MB/s eta 0:00:04
#    ------- -------------------------------- 0.6/3.5 MB 1.2 MB/s eta 0:00:03
#    -------- ------------------------------- 0.8/3.5 MB 1.3 MB/s eta 0:00:03
#    ---------- ----------------------------- 0.9/3.5 MB 1.4 MB/s eta 0:00:02
#    ----------- ---------------------------- 1.1/3.5 MB 1.6 MB/s eta 0:00:02
#    ------------- -------------------------- 1.2/3.5 MB 1.7 MB/s eta 0:00:02
#    --------------- ------------------------ 1.3/3.5 MB 1.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 1.5/3.5 MB 1.8 MB/s eta 0:00:02
#    ------------------ --------------------- 1.7/3.5 MB 1.9 MB/s eta 0:00:01
#    -------------------- ------------------- 1.8/3.5 MB 2.0 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.0/3.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 2.2/3.5 MB 2.1 MB/s eta 0:00:01
#    ------------------------- -------------- 2.3/3.5 MB 2.2 MB/s eta 0:00:01
#    --------------------------- ------------ 2.4/3.5 MB 2.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.6/3.5 MB 2.2 MB/s eta 0:00:01
#    ------------------------------ --------- 2.7/3.5 MB 2.2 MB/s eta 0:00:01
#    -------------------------------- ------- 2.9/3.5 MB 2.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.1/3.5 MB 2.4 MB/s eta 0:00:01
#    ------------------------------------- -- 3.3/3.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------  3.5/3.5 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 2.5 MB/s eta 0:00:00
# Installing collected packages: confluent-kafka
# Successfully installed confluent-kafka-2.5.0
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from confluent_kafka import Producer
import json
import time
import random


conf = {
    'bootstrap.servers': 'pkc-921jm.us-east-2.aws.confluent.cloud:9092',
    'security.protocol': 'SASL_SSL',
    'sasl.mechanisms': 'PLAIN',
    'sasl.username': '6UX76KJG3N363E2H',
    'sasl.password': 'dWAj0CPM50FkljxdqW1z/1yH2am/FQdb7MicZ01vr/F0Zu8WRFx6Fx0fDpXWrt06',
}

# add topic_name here 
topic = 'demo_topic'

def generate_event(event_type):
    event = {
        "eventType": event_type,
        "customerId": str(random.randint(10000, 99999)),
        "productId": str(random.randint(1000, 9999)),
        "timestamp": time.strftime('%Y-%m-%dT%H:%M:%S'),
        "metadata": {}
    }
    
    if event_type == "productView":
        event["metadata"]["category"] = random.choice(["Electronics", "Clothing", "Home & Kitchen", "Books"])
        event["metadata"]["source"] = random.choice(["Advertisement", "Search", "Direct"])
    elif event_type == "addToCart":
        event["quantity"] = random.randint(1, 5)
    elif event_type == "purchase":
        event["quantity"] = random.randint(1, 5)
        event["totalAmount"] = round(random.uniform(10, 500), 2)
        event["paymentMethod"] = random.choice(["Credit Card", "Debit Card", "PayPal"])
    elif event_type == "recommendationClick":
        event["recommendedProductId"] = str(random.randint(1000, 9999))
        event["algorithm"] = random.choice(["collaborative_filtering", "content_based"])
    return event

producer = Producer(conf)

def send_event(event):
    try:
        producer.produce(topic, json.dumps(event))
        print("Event produced:", event)
    except Exception as e:
        print("Error:", e)

def main():
    while True:
        event_type = random.choice(["productView", "addToCart", "purchase", "recommendationClick"])
        event = generate_event(event_type)
        print(event)
        send_event(event)
        time.sleep(random.uniform(0.5, 2))

if __name__ == "__main__":
    main()
# Out:
# {'eventType': 'recommendationClick', 'customerId': '78595', 'productId': '4158', 'timestamp': '2024-08-03T16:32:39', 'metadata': {}, 'recommendedProductId': '7520', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '78595', 'productId': '4158', 'timestamp': '2024-08-03T16:32:39', 'metadata': {}, 'recommendedProductId': '7520', 'algorithm': 'content_based'}
# {'eventType': 'productView', 'customerId': '83038', 'productId': '8568', 'timestamp': '2024-08-03T16:32:40', 'metadata': {'category': 'Books', 'source': 'Direct'}}
# Event produced: {'eventType': 'productView', 'customerId': '83038', 'productId': '8568', 'timestamp': '2024-08-03T16:32:40', 'metadata': {'category': 'Books', 'source': 'Direct'}}
# {'eventType': 'purchase', 'customerId': '28489', 'productId': '3852', 'timestamp': '2024-08-03T16:32:42', 'metadata': {}, 'quantity': 2, 'totalAmount': 310.33, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '28489', 'productId': '3852', 'timestamp': '2024-08-03T16:32:42', 'metadata': {}, 'quantity': 2, 'totalAmount': 310.33, 'paymentMethod': 'Credit Card'}
# {'eventType': 'purchase', 'customerId': '66454', 'productId': '6553', 'timestamp': '2024-08-03T16:32:43', 'metadata': {}, 'quantity': 5, 'totalAmount': 192.75, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '66454', 'productId': '6553', 'timestamp': '2024-08-03T16:32:43', 'metadata': {}, 'quantity': 5, 'totalAmount': 192.75, 'paymentMethod': 'PayPal'}
# {'eventType': 'recommendationClick', 'customerId': '91961', 'productId': '8763', 'timestamp': '2024-08-03T16:32:44', 'metadata': {}, 'recommendedProductId': '9400', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '91961', 'productId': '8763', 'timestamp': '2024-08-03T16:32:44', 'metadata': {}, 'recommendedProductId': '9400', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'purchase', 'customerId': '24893', 'productId': '6672', 'timestamp': '2024-08-03T16:32:45', 'metadata': {}, 'quantity': 1, 'totalAmount': 194.64, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '24893', 'productId': '6672', 'timestamp': '2024-08-03T16:32:45', 'metadata': {}, 'quantity': 1, 'totalAmount': 194.64, 'paymentMethod': 'Credit Card'}
# {'eventType': 'productView', 'customerId': '79896', 'productId': '3802', 'timestamp': '2024-08-03T16:32:46', 'metadata': {'category': 'Clothing', 'source': 'Direct'}}
# Event produced: {'eventType': 'productView', 'customerId': '79896', 'productId': '3802', 'timestamp': '2024-08-03T16:32:46', 'metadata': {'category': 'Clothing', 'source': 'Direct'}}
# {'eventType': 'productView', 'customerId': '29335', 'productId': '2211', 'timestamp': '2024-08-03T16:32:47', 'metadata': {'category': 'Books', 'source': 'Direct'}}
# Event produced: {'eventType': 'productView', 'customerId': '29335', 'productId': '2211', 'timestamp': '2024-08-03T16:32:47', 'metadata': {'category': 'Books', 'source': 'Direct'}}
# {'eventType': 'purchase', 'customerId': '71748', 'productId': '2263', 'timestamp': '2024-08-03T16:32:49', 'metadata': {}, 'quantity': 2, 'totalAmount': 247.79, 'paymentMethod': 'Credit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '71748', 'productId': '2263', 'timestamp': '2024-08-03T16:32:49', 'metadata': {}, 'quantity': 2, 'totalAmount': 247.79, 'paymentMethod': 'Credit Card'}
# {'eventType': 'recommendationClick', 'customerId': '62480', 'productId': '9699', 'timestamp': '2024-08-03T16:32:50', 'metadata': {}, 'recommendedProductId': '7764', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '62480', 'productId': '9699', 'timestamp': '2024-08-03T16:32:50', 'metadata': {}, 'recommendedProductId': '7764', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'recommendationClick', 'customerId': '70937', 'productId': '2390', 'timestamp': '2024-08-03T16:32:51', 'metadata': {}, 'recommendedProductId': '2984', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '70937', 'productId': '2390', 'timestamp': '2024-08-03T16:32:51', 'metadata': {}, 'recommendedProductId': '2984', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'purchase', 'customerId': '64238', 'productId': '4367', 'timestamp': '2024-08-03T16:32:52', 'metadata': {}, 'quantity': 3, 'totalAmount': 275.54, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '64238', 'productId': '4367', 'timestamp': '2024-08-03T16:32:52', 'metadata': {}, 'quantity': 3, 'totalAmount': 275.54, 'paymentMethod': 'PayPal'}
# {'eventType': 'productView', 'customerId': '97873', 'productId': '6710', 'timestamp': '2024-08-03T16:32:53', 'metadata': {'category': 'Clothing', 'source': 'Direct'}}
# Event produced: {'eventType': 'productView', 'customerId': '97873', 'productId': '6710', 'timestamp': '2024-08-03T16:32:53', 'metadata': {'category': 'Clothing', 'source': 'Direct'}}
# {'eventType': 'addToCart', 'customerId': '41628', 'productId': '1517', 'timestamp': '2024-08-03T16:32:55', 'metadata': {}, 'quantity': 1}
# Event produced: {'eventType': 'addToCart', 'customerId': '41628', 'productId': '1517', 'timestamp': '2024-08-03T16:32:55', 'metadata': {}, 'quantity': 1}
# {'eventType': 'recommendationClick', 'customerId': '64893', 'productId': '6160', 'timestamp': '2024-08-03T16:32:56', 'metadata': {}, 'recommendedProductId': '7436', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '64893', 'productId': '6160', 'timestamp': '2024-08-03T16:32:56', 'metadata': {}, 'recommendedProductId': '7436', 'algorithm': 'content_based'}
# {'eventType': 'productView', 'customerId': '37068', 'productId': '9386', 'timestamp': '2024-08-03T16:32:58', 'metadata': {'category': 'Books', 'source': 'Search'}}
# Event produced: {'eventType': 'productView', 'customerId': '37068', 'productId': '9386', 'timestamp': '2024-08-03T16:32:58', 'metadata': {'category': 'Books', 'source': 'Search'}}
# {'eventType': 'purchase', 'customerId': '29274', 'productId': '1989', 'timestamp': '2024-08-03T16:33:00', 'metadata': {}, 'quantity': 4, 'totalAmount': 177.4, 'paymentMethod': 'PayPal'}
# Event produced: {'eventType': 'purchase', 'customerId': '29274', 'productId': '1989', 'timestamp': '2024-08-03T16:33:00', 'metadata': {}, 'quantity': 4, 'totalAmount': 177.4, 'paymentMethod': 'PayPal'}
# {'eventType': 'purchase', 'customerId': '40775', 'productId': '1215', 'timestamp': '2024-08-03T16:33:02', 'metadata': {}, 'quantity': 2, 'totalAmount': 58.24, 'paymentMethod': 'Debit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '40775', 'productId': '1215', 'timestamp': '2024-08-03T16:33:02', 'metadata': {}, 'quantity': 2, 'totalAmount': 58.24, 'paymentMethod': 'Debit Card'}
# {'eventType': 'purchase', 'customerId': '49771', 'productId': '5633', 'timestamp': '2024-08-03T16:33:02', 'metadata': {}, 'quantity': 5, 'totalAmount': 179.18, 'paymentMethod': 'Debit Card'}
# Event produced: {'eventType': 'purchase', 'customerId': '49771', 'productId': '5633', 'timestamp': '2024-08-03T16:33:02', 'metadata': {}, 'quantity': 5, 'totalAmount': 179.18, 'paymentMethod': 'Debit Card'}
# {'eventType': 'recommendationClick', 'customerId': '27773', 'productId': '4393', 'timestamp': '2024-08-03T16:33:03', 'metadata': {}, 'recommendedProductId': '9942', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '27773', 'productId': '4393', 'timestamp': '2024-08-03T16:33:03', 'metadata': {}, 'recommendedProductId': '9942', 'algorithm': 'content_based'}
# {'eventType': 'recommendationClick', 'customerId': '17665', 'productId': '2342', 'timestamp': '2024-08-03T16:33:04', 'metadata': {}, 'recommendedProductId': '8669', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '17665', 'productId': '2342', 'timestamp': '2024-08-03T16:33:04', 'metadata': {}, 'recommendedProductId': '8669', 'algorithm': 'content_based'}
# {'eventType': 'recommendationClick', 'customerId': '39000', 'productId': '7910', 'timestamp': '2024-08-03T16:33:05', 'metadata': {}, 'recommendedProductId': '7075', 'algorithm': 'collaborative_filtering'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '39000', 'productId': '7910', 'timestamp': '2024-08-03T16:33:05', 'metadata': {}, 'recommendedProductId': '7075', 'algorithm': 'collaborative_filtering'}
# {'eventType': 'productView', 'customerId': '58163', 'productId': '4397', 'timestamp': '2024-08-03T16:33:06', 'metadata': {'category': 'Clothing', 'source': 'Advertisement'}}
# Event produced: {'eventType': 'productView', 'customerId': '58163', 'productId': '4397', 'timestamp': '2024-08-03T16:33:06', 'metadata': {'category': 'Clothing', 'source': 'Advertisement'}}
# {'eventType': 'addToCart', 'customerId': '66917', 'productId': '1818', 'timestamp': '2024-08-03T16:33:07', 'metadata': {}, 'quantity': 2}
# Event produced: {'eventType': 'addToCart', 'customerId': '66917', 'productId': '1818', 'timestamp': '2024-08-03T16:33:07', 'metadata': {}, 'quantity': 2}
# {'eventType': 'recommendationClick', 'customerId': '88064', 'productId': '4542', 'timestamp': '2024-08-03T16:33:08', 'metadata': {}, 'recommendedProductId': '2173', 'algorithm': 'content_based'}
# Event produced: {'eventType': 'recommendationClick', 'customerId': '88064', 'productId': '4542', 'timestamp': '2024-08-03T16:33:08', 'metadata': {}, 'recommendedProductId': '2173', 'algorithm': 'content_based'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 59
#      56         time.sleep(random.uniform(0.5, 2))
#      58 if __name__ == "__main__":
# ---> 59     main()
#
# Cell In[2], line 56, in main()
#      54 print(event)
#      55 send_event(event)
# ---> 56 time.sleep(random.uniform(0.5, 2))
#
# KeyboardInterrupt:
